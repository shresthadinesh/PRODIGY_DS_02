# %% [markdown]
# ## importing numpy and pands

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load the csv file

# %%
# Loading the Titanic dataset into a Pandas DataFrame
df = pd.read_csv("Titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Returns the number of rows and columns in the DataFrame as a tuple (rows, columns)
# Out:
# (891, 12)

# %%
df.info()
# Displays a summary of the DataFrame, including column names, data types, and non-null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
 #  summary statistics for numerical columns, including count, mean, std, min, and percentiles
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Countint the number of missing (null) values in each column of the DataFrame
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Dropping the unnecessary colums
df.drop(columns = 'Cabin', axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
# Filling the missing values
df['Age'].fillna(df['Age'].mean(), inplace=True)
# Out:
# C:\Users\shres\AppData\Local\Temp\ipykernel_8816\1560013138.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace= True)
# Out:
# C:\Users\shres\AppData\Local\Temp\ipykernel_8816\4228943529.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace= True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
# checking for duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
# There is no duplicated and missing values

# %% [markdown]
# ## CHECKING THE SURVIVAL OF PEOPLE

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Countplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x= 'Survived', data=df, palette= 'viridis',)
plt.xlabel("Survival Status")
plt.ylabel("Number of People")
plt.xticks(ticks= [0,1], labels= ['Not Survived', 'Survived'])
plt.show()
# Out:
# C:\Users\shres\AppData\Local\Temp\ipykernel_8816\1091961282.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= 'Survived', data=df, palette= 'viridis',)

# %% [markdown]
# ### PieChart

# %%
import matplotlib.pyplot as plt

# Count the number of survivors and non-survivors
survival_counts = df['Survived'].value_counts()

# Create a pie chart
plt.pie(survival_counts, labels=['Not Survived', 'Survived'], autopct='%1.2f%%', colors=['red', 'green'])
# autopct='%1.2f%%' Displays the percentage of each segment on the chart, rounded to two decimal place.

# Set the title
plt.title('Survival Status Distribution')

# Display the plot
plt.show()

# %% [markdown]
# ## survived from different gender

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# CountPlot 
sns.countplot(x = 'Sex', data = df, palette = 'viridis')
plt.title("No of survived people by gender")
plt.xlabel("Gender")
plt.ylabel("Number of People")
plt.show()
# Out:
# C:\Users\shres\AppData\Local\Temp\ipykernel_8816\755604910.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Sex', data = df, palette = 'viridis')

# %%
# countplot for survived and unsurvived by gender
sns.countplot(x = "Survived", data = df, hue = "Sex", palette = "bright")
plt.title("Number of Survived and Unsurvived people by Gender")
plt.xlabel("Survival of People")
plt.ylabel("Number of People")
plt.xticks(ticks = [0,1], labels = [ 'Not Survived', 'Survived'])
plt.show()

# %%
df[df['Sex'] == 'male'].Survived.groupby(df.Survived).count()
# Out:
# Survived
# 0    468
# 1    109
# Name: Survived, dtype: int64

# %%
df[df['Sex'] == 'male'].Survived.groupby(df.Survived).count().plot(
    kind='pie', 
    figsize=(3, 6), 
    explode=[0, 0.05], 
    autopct='%1.1f%%', 
    labels=["Not Survived", "Survived"]
)
plt.ylabel("")
plt.title("Male Survival Rate")
plt.show()

#explode=[0, 0.05] → Slightly separates the "Survived" slice from the pie chart to highlight it

# %%
df[df['Sex'] == 'female'].Survived.groupby(df.Survived).count().plot(
    kind = 'pie',
    figsize = (3,6),
    explode = [0, 0.05],
    autopct='%1.1f%%',
    labels = ['Not Survived', 'Survived']
)
plt.title("Female survival rate")
plt.ylabel("")
plt.show()

# %% [markdown]
# #### Survival rate of female is higher

# %% [markdown]
# ### Population of different passenger class

# %%
sns.countplot(x = 'Pclass', hue = 'Pclass',data = df, palette = "flare")
plt.title("Population of different passenger classs")
plt.xlabel("Class Type")
plt.ylabel("Number of Passenger")
plt.show()

# %% [markdown]
# #### People survived from different Passenger Class

# %%
sns.countplot(x = 'Survived',data = df, hue = "Pclass", palette = 'viridis')
plt.title("People survived from different passenger class")
plt.xlabel("Survival Status")
plt.ylabel("Number of people")
plt.xticks(ticks = [0,1], labels = ['Not Survived', 'Survived'])
plt.show()

# %%
#### Survived people by sex
sns.catplot(x= 'Pclass', hue= 'Survived', col= 'Sex', kind= 'count', data= df,
palette= 'rocket_r')
plt.tight_layout()

# %%
# Though population of Pclass 3 was the highest, yet they had the least survival rate.
# Males from Pclass 3 had the least survival rate.

# %% [markdown]
# #### PEOPLE SURVIVED FROM DIFFERENT EMBARKMENT

# %%
sns.countplot(x= 'Embarked', data= df, hue = "Embarked" , palette= 'coolwarm',)
plt.xlabel("Embarked")
plt.ylabel("Number of People")
plt.show()

# %%
sns.countplot(x='Survived', hue= 'Embarked', data= df, palette= 'Set2',)
plt.xlabel("Survival Status")
plt.ylabel("Number of People")
plt.xticks(ticks= [0,1], labels= ['Nor Survived', 'Survived'])
plt.show()

# %%
fig,axes= plt.subplots(1,2, figsize= (12,6))
sns.countplot(x= 'SibSp', data= df, ax= axes[0], hue = "SibSp", palette= 'hls')
sns.countplot(x= 'Parch', data= df, ax= axes[1], hue = "Parch", palette= 'hls')
plt.show()

# %%
sns.countplot(x= 'Survived', hue= 'SibSp', data= df, palette= 'Paired')
plt.xticks(ticks= [0,1], labels= ['Not survived', 'Survived'])
plt.xlabel("Survival Status")
plt.ylabel("Number of People")
plt.title("Survival Population of SibSp")
plt.show()

sns.countplot(x= 'Survived', hue= 'Parch', data= df, palette= 'Paired')
plt.xticks(ticks= [0,1], labels= ['Not survived', 'Survived'])
plt.xlabel("Survival Status")
plt.ylabel("Number of People")
plt.title("Survival Population of Parch")
plt.show()

# %% [markdown]
# #### DISTRIBUTION OF FARE AND AGE

# %%
fig,axes= plt.subplots(1,2, figsize= (12,6))
sns.histplot(df['Fare'], kde= True, ax= axes[0])
sns.histplot(df['Age'].dropna(), kde= True, ax= axes[1])
plt.show()

# %% [markdown]
# #### SURVIVAL RATE IN DIFFERENT AGE GROUP

# %%
# Defining cut points & label names

cut_points= [0,5,12,18,35,60,100]
label_names= ['Infant', 'Child', 'Teenager', 'Young Adult', 'Adult', 'Senior']

# Creating the Age categories in column
df['Age_categories']= pd.cut(df['Age'], bins= cut_points, labels= label_names, right= False)

# Creating a pivot table for survivalnrates
age_pivot= df.pivot_table(index= "Age_categories", values= "Survived")

# Defining colors for each bar
colors= ['blue', 'green', 'orange', 'purple', 'pink', 'brown']

# Plotting the bar chart
fig, ax= plt.subplots()
bars= ax.bar(age_pivot.index, age_pivot['Survived'], color= colors)

# Adding legend
handles= [plt.Rectangle((0,0), 1,1, color= colors[i]) for i in
range(len(colors))]
ax.legend(handles, label_names)
ax.set_title('Survival Rates by Age Category')
ax.set_xlabel('Age Category')
ax.set_ylabel('Survival Rate')
plt.xticks(rotation= 40)
plt.show()
# Out:
# C:\Users\shres\AppData\Local\Temp\ipykernel_8816\1670745951.py:10: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   age_pivot= df.pivot_table(index= "Age_categories", values= "Survived")

# %%
sns.histplot(x= 'Fare', hue= 'Survived', data= df, kde= True)
plt.legend(labels= ['Survived', 'Not Survived'])
plt.show()

# %%
sns.histplot(x='Age', hue='Survived', data=df, kde=True)
plt.legend(labels=['Survived', 'Not Survived'])
plt.title("Age Distribution by Survival Status")
plt.show()

# %% [markdown]
# #### CORRELATION

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df['Age'] = df['Age'].astype(int)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Embarked Age_categories
# 0      0         A/5 21171   7.2500        S    Young Adult
# 1      0          PC 17599  71.2833        C          Adult
# 2      0  STON/O2. 3101282   7.9250        S    Young Adult
# 3      0            113803  53.1000        S          Adult
# ...

# %%
df['Sex'] = df['Sex'].map({'male': 1, 'female': 0})
df['Embarked'] = df['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0   38      1      0
# 2                             Heikkinen, Miss. Laina    0   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0   35      1      0
# 4                           Allen, Mr. William Henry    1   35      0      0
#
#              Ticket     Fare  Embarked Age_categories
# 0         A/5 21171   7.2500         0    Young Adult
# 1          PC 17599  71.2833         1          Adult
# 2  STON/O2. 3101282   7.9250         0    Young Adult
# 3            113803  53.1000         0          Adult
# ...

# %%
df_num = df[['Fare', 'Parch', 'SibSp', 'Age', 'Sex', 'Pclass', 'Embarked', 'Survived']]

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))  # Adjust size
sns.heatmap(df_num.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# Conclusion: Fare, sex, Pclass, Embarked has correlation with survived column
